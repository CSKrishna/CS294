# %%
# %run train_pg.py CartPole-v0 -n 100 -b 1000 -e 5 -dna --exp_name sb_no_rtg_dna
# Out:
# Running experiment with seed 1
# Running experiment with seed 11
# Running experiment with seed 21
# Running experiment with seed 31
# Running experiment with seed 41

# %%
# %run plot.py data/sb_no_rtg_dna_CartPole-v0_04-01-2018_19-57-20 --value AverageReturn

# %%
# %run train_pg.py CartPole-v0 -n 100 -b 1000 -e 5 -rtg -dna --exp_name sb_rtg_dna
# Out:
# Running experiment with seed 1
# Running experiment with seed 11
# Running experiment with seed 21
# Running experiment with seed 31
# Running experiment with seed 41

# %%
# %run plot.py data/sb_rtg_dna_CartPole-v0_02-01-2018_19-04-48 --value AverageReturn

# %%
# %run train_pg.py CartPole-v0 -n 100 -b 1000 -e 5 -rtg --exp_name sb_rtg_na
# Out:
# Running experiment with seed 1
# Running experiment with seed 11
# Running experiment with seed 21
# Running experiment with seed 31
# Running experiment with seed 41

# %%
# %run plot.py data/sb_rtg_na_CartPole-v0_02-01-2018_19-09-39 --value AverageReturn

# %%
% run plot.py data/sb_no_rtg_dna_CartPole-v0_02-01-2018_17-48-42 data/sb_rtg_dna_CartPole-v0_02-01-2018_19-04-48 data/sb_rtg_na_CartPole-v0_02-01-2018_19-09-39

# %%
# %run train_pg.py CartPole-v0 -n 100 -b 5000 -e 5 -dna --exp_name lb_no_rtg_dna
# Out:
# Running experiment with seed 1
# Running experiment with seed 11
# Running experiment with seed 21
# Running experiment with seed 31
# Running experiment with seed 41

# %%
# %run plot.py data/lb_no_rtg_dna_CartPole-v0_02-01-2018_19-21-15 --value AverageReturn

# %%
# %run train_pg.py CartPole-v0 -n 100 -b 5000 -e 5 -rtg -dna --exp_name lb_rtg_dna
# Out:
# Running experiment with seed 1
# Running experiment with seed 11
# Running experiment with seed 21
# Running experiment with seed 31
# Running experiment with seed 41

# %%
# %run plot.py data/lb_rtg_dna_CartPole-v0_02-01-2018_19-54-34 --value AverageReturn

# %%
# %run train_pg.py CartPole-v0 -n 100 -b 5000 -e 5 -rtg --exp_name lb_rtg_na
# Out:
# Running experiment with seed 1
# Running experiment with seed 11
# Running experiment with seed 21
# Running experiment with seed 31
# Running experiment with seed 41

# %%
# %run plot.py data/lb_rtg_na_CartPole-v0_06-01-2018_10-02-59 --value AverageReturn

# %%
% run plot.py data/lb_no_rtg_dna_CartPole-v0_02-01-2018_19-21-15 data/lb_rtg_dna_CartPole-v0_02-01-2018_19-54-34 data/lb_rtg_na_CartPole-v0_06-01-2018_10-02-59

# %%
# %run train_pg.py CartPole-v0 -n 100 -b 1000 -e 5 -rtg -bl --exp_name sb_rtg_na_bl
# Out:
# Running experiment with seed 1
# Running experiment with seed 11
# Running experiment with seed 21
# Running experiment with seed 31
# Running experiment with seed 41

# %%
# %run plot.py data/sb_rtg_na_bl_CartPole-v0_21-01-2018_15-14-21 --value AverageReturn

# %%
# %run train_pg.py CartPole-v0 -n 100 -b 1000 -e 5 -rtg -bl --exp_name sb_rtg_na_bl
# Out:
# Running experiment with seed 1
# Running experiment with seed 11
# Running experiment with seed 21
# Running experiment with seed 31
# Running experiment with seed 41

# %%
# %run plot.py data/sb_rtg_na_bl_CartPole-v0_21-01-2018_15-20-11 --value AverageReturn

# %%
# %run train_pg.py CartPole-v0 -n 100 -b 5000 -e 5 -rtg -bl --exp_name lb_rtg_na_bl
# Out:
# Running experiment with seed 1
# Running experiment with seed 11
# Running experiment with seed 21
# Running experiment with seed 31
# Running experiment with seed 41

# %%
# %run plot.py data/lb_rtg_na_bl_CartPole-v0_21-01-2018_15-33-18 --value AverageReturn
